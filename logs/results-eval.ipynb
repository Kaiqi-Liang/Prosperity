# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# Disable scientific notation globally
mpl.rcParams['axes.formatter.useoffset'] = False
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df = pd.read_csv('./round4/test3.csv', delimiter=";")

# %%
df[df['product'] == "AMETHYSTS"].head(10)
# Out:
#     day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 2     2          0  AMETHYSTS         9996             2      9995.00
# 9     2        100  AMETHYSTS         9996             2      9995.00
# 14    2        200  AMETHYSTS         9995            20          NaN
# 27    2        300  AMETHYSTS         9996             1      9995.00
# 30    2        400  AMETHYSTS         9995            30          NaN
# 37    2        500  AMETHYSTS        10000             6      9995.00
# 42    2        600  AMETHYSTS         9995            29          NaN
# 55    2        700  AMETHYSTS        10000             4      9996.00
# 62    2        800  AMETHYSTS         9996             1      9995.00
# 65    2        900  AMETHYSTS        10002             1      9996.00
#
#     bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 2          25.00          NaN           NaN        10004             2
# 9          28.00          NaN           NaN         9998             1
# 14           NaN          NaN           NaN        10005            20
# 27         20.00          NaN           NaN        10004             1
# 30           NaN          NaN           NaN        10005            30
# 37         22.00          NaN           NaN        10005            22
# 42           NaN          NaN           NaN        10005            29
# 55          1.00      9995.00         29.00        10004             1
# 62         27.00          NaN           NaN         9998             1
# 65          1.00      9995.00         24.00        10004             1
#
#     ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 2      10005.00         25.00          NaN           NaN   10000.00
# 9      10004.00          2.00     10005.00         28.00    9997.00
# 14          NaN           NaN          NaN           NaN   10000.00
# 27     10005.00         20.00          NaN           NaN   10000.00
# 30          NaN           NaN          NaN           NaN   10000.00
# 37          NaN           NaN          NaN           NaN   10002.50
# 42          NaN           NaN          NaN           NaN   10000.00
# 55     10005.00         29.00          NaN           NaN   10002.00
# 62     10004.00          1.00     10005.00         27.00    9997.00
# 65     10005.00         24.00          NaN           NaN   10003.00
#
#     profit_and_loss
# 2              0.00
# 9              0.00
# 14             2.00
# 27             2.00
# 30             2.00
# 37             2.00
# 42             2.00
# 55             2.00
# 62             2.00
# 65             4.00

# %%
df[df['profit_and_loss']<0]
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 66      2        900  STARFRUIT         5022             1      5021.00
# 72      2       1000  STARFRUIT         5021            22          NaN
# 77      2       1100  STARFRUIT         5022            27          NaN
# 88      2       1200  STARFRUIT         5022            24          NaN
# 96      2       1300  STARFRUIT         5021            31          NaN
# ...   ...        ...        ...          ...           ...          ...
# 6970    2      99500  STARFRUIT         5010            24          NaN
# 6973    2      99600  STARFRUIT         5010            30          NaN
# 6979    2      99700  STARFRUIT         5010            30          NaN
# 6990    2      99800  STARFRUIT         5011             2      5010.00
# 6997    2      99900  STARFRUIT         5011             7      5010.00
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 66           24.00          NaN           NaN         5028            25
# 72             NaN          NaN           NaN         5028            22
# 77             NaN          NaN           NaN         5027             4
# 88             NaN          NaN           NaN         5028             2
# 96             NaN          NaN           NaN         5022             1
# ...            ...          ...           ...          ...           ...
# 6970           NaN          NaN           NaN         5017            24
# 6973           NaN          NaN           NaN         5017            30
# 6979           NaN          NaN           NaN         5011             1
# 6990         26.00          NaN           NaN         5015             6
# 6997         21.00          NaN           NaN         5017            21
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 66            NaN           NaN          NaN           NaN    5025.00
# 72            NaN           NaN          NaN           NaN    5024.50
# 77        5028.00          1.00      5029.00         26.00    5024.50
# 88        5029.00         22.00          NaN           NaN    5025.00
# 96        5028.00         31.00          NaN           NaN    5021.50
# ...           ...           ...          ...           ...        ...
# 6970          NaN           NaN          NaN           NaN    5013.50
# 6973          NaN           NaN          NaN           NaN    5013.50
# 6979      5017.00         30.00          NaN           NaN    5010.50
# 6990      5017.00         28.00          NaN           NaN    5013.00
# 6997          NaN           NaN          NaN           NaN    5014.00
#
#       profit_and_loss
# 66             -39.47
# 72             -37.24
# 77             -35.38
# 88             -34.98
# 96             -41.11
# ...               ...
# 6970          -161.78
# 6973          -161.75
# 6979          -159.92
# 6990          -160.02
# 6997          -163.23
#
# [991 rows x 17 columns]

# %%
#  Graph the 'profit_and_loss' for each unique product
for product in df['product'].unique():
    df[df['product'] == product].plot(x='timestamp', y='profit_and_loss', title=product, figsize=(3, 2))

# %%
df
# Out:
#       day  timestamp       product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       2          0         ROSES        14421            30      14420.0
# 1       2          0  STRAWBERRIES         4036           181          NaN
# 2       2          0     AMETHYSTS         9996             2       9995.0
# 3       2          0       ORCHIDS         1053             7       1052.0
# 4       2          0     STARFRUIT         5023             1       5022.0
# ...   ...        ...           ...          ...           ...          ...
# 6995    2      99900     AMETHYSTS         9998             3       9996.0
# 6996    2      99900  STRAWBERRIES         4042           274          NaN
# 6997    2      99900     STARFRUIT         5011             7       5010.0
# 6998    2      99900         ROSES        14405            64          NaN
# 6999    2      99900     CHOCOLATE         7898           135          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0             42.0          NaN           NaN        14422            72
# 1              NaN          NaN           NaN         4037           181
# 2             25.0          NaN           NaN        10004             2
# 3              2.0       1046.0          46.0         1059             7
# 4             27.0          NaN           NaN         5029            27
# ...            ...          ...           ...          ...           ...
# 6995           1.0       9995.0          20.0        10004             1
# 6996           NaN          NaN           NaN         4044           274
# 6997          21.0          NaN           NaN         5017            21
# 6998           NaN          NaN           NaN        14407            64
# 6999           NaN          NaN           NaN         7900           135
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 0             NaN           NaN          NaN           NaN    14421.5
# 1             NaN           NaN          NaN           NaN     4036.5
# 2         10005.0          25.0          NaN           NaN    10000.0
# 3          1060.0           2.0       1067.0          46.0     1056.0
# 4             NaN           NaN          NaN           NaN     5026.0
# ...           ...           ...          ...           ...        ...
# 6995      10005.0          20.0          NaN           NaN    10001.0
# 6996          NaN           NaN          NaN           NaN     4043.0
# 6997          NaN           NaN          NaN           NaN     5014.0
# 6998          NaN           NaN          NaN           NaN    14406.0
# 6999          NaN           NaN          NaN           NaN     7899.0
#
#       profit_and_loss
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ...               ...
# 6995       914.000000
# 6996         0.000000
# 6997      -163.230469
# 6998         0.000000
# 6999         0.000000
#
# [7000 rows x 17 columns]

# %%
# Plot the 'bid_price_1' and 'ask_price_1' for each unique product as boxplots
filtered_df = df
for product in filtered_df['product'].unique():
    filtered_df[filtered_df['product'] == product].plot(x='timestamp', y=['bid_price_1'], title=product)

# %%
# Plot the midmarket (average of 'bid_price_1' and 'ask_price_1') for each unique product
df['midmarket'] = (df['bid_price_1'] + df['ask_price_1']) / 2
for product in df['product'].unique():
    plot = df[df['product'] == product].plot(x='timestamp', y='midmarket', title=product, figsize=(3, 2))

# %%
# Sum all the 'profit_and_loss' for each product
df.groupby('product')['profit_and_loss'].sum()
# Out:
# product
# AMETHYSTS    3.909400e+04
# ORCHIDS      8.419083e+07
# STARFRUIT    4.132688e+04
# Name: profit_and_loss, dtype: float64

# %%
# plot the sum of 'profit_and_loss' for each timestamp
df.groupby('timestamp')['profit_and_loss'].sum().plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='timestamp'>
