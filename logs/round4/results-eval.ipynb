# %%
import pandas as pd

# %%
df = pd.read_csv('round3-results.csv', delimiter=";")

# %%
df.head(10)
# Out:
#    day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    1          0  AMETHYSTS         9998             3       9996.0
# 1    1          0    ORCHIDS         1094            10       1093.0
# 2    1          0  STARFRUIT         5048             1       5047.0
# 3    1        100  STARFRUIT         5047            26          NaN
# 4    1        100    ORCHIDS         1094             6       1093.0
# 5    1        100  AMETHYSTS         9995            26          NaN
# 6    1        200  AMETHYSTS         9996             2       9995.0
# 7    1        200    ORCHIDS         1093             6       1092.0
# 8    1        200  STARFRUIT         5053             1       5048.0
# 9    1        300  AMETHYSTS         9996             1       9995.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           1.0       9995.0          21.0        10004             1
# ...

# %%
import matplotlib

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='bid_price_1')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='bid_price_1')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='bid_price_2')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='bid_price_2')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='ask_price_1')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='ask_price_1')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='ask_price_2')
plot.ticklabel_format(useOffset=False)

# %%
plot = df[df['product'] == "AMETHYSTS"].plot(x='timestamp', y='ask_price_3')
plot.ticklabel_format(useOffset=False)

# %%
# Graph the 'profit_and_loss' for each uniqie product with plotly
for product in df['product'].unique():
    df[df['product'] == product].plot(x='timestamp', y='mid_price', title=product)

# %%
# Graph the 'profit_and_loss' for each uniqie product with plotly
for product in df['product'].unique():
    df[df['product'] == product].plot(x='timestamp', y='profit_and_loss', title=product)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mid_market'
#
# ...
