# %%
import pandas as pd

# %%
df = pd.read_csv('prices_round_4_day_1.csv', index_col=0, delimiter=";")

# %%
df.head()
# Out:
#      timestamp         product  bid_price_1  bid_volume_1  bid_price_2  \
# day
# 1            0         COCONUT         9999           200          NaN
# 1            0  COCONUT_COUPON          637            39          NaN
# 1          100         COCONUT         9999           104       9998.0
# 1          100  COCONUT_COUPON          637            33          NaN
# 1          200         COCONUT         9998           133       9997.0
#
#      bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# day
# 1             NaN          NaN           NaN        10001           200
# 1             NaN          NaN           NaN          638            39
# 1            44.0          NaN           NaN        10000           104
# 1             NaN          NaN           NaN          638            33
# 1            62.0          NaN           NaN         9999           133
#
#      ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# day
# ...

# %%
# Graph the "mid_price" of the "COCONUT" product and "COCONUT_COUPON" product on the same plot
# df.plot(x='timestamp', y='mid_price', kind='line', title='Coconut Prices')
# df.plot(x='timestamp', y='COCONUT_COUPON', kind='line', title='Coconut Prices')
plot = df[df['product'] == 'COCONUT'].plot(x='timestamp', y='mid_price', kind='line', title='Coconut Prices', figsize=(5, 5))
plot2 = df[df['product'] == 'COCONUT_COUPON'].plot(x='timestamp', y='mid_price', kind='line', title='Coconut Coupon Prices', figsize=(5.2, 5))
# df[df['product'] == 'COCONUT_COUPON'].plot(x='timestamp', y='mid_price', kind='line', title='Coconut Prices', ax=plot)
# df[df['COCONUT_COUPON']]
